# %%
import os
import re
import json
import openai

# %%
def extract_from_raw_text(raw_text):
    # Define regex patterns for the fields we want to extract
    patterns = {
        "Food": r"has_food_constituent:\s*(.+?)\s*has_dose:",
        "Phenotype": r"has_phenotype:\s*(.+)",
        "Target_population": r"has_target_population:\s*(.+?)\s*has_evidence:",
        "Citations": r"has_citations:\s*(.+?)\s*has_phenotype:",
    }
    # Extract values using the defined patterns
    extracted_data = {}
    for key, pattern in patterns.items():
        match = re.search(pattern, raw_text, re.DOTALL)
        if match:
            text = match.group(1).strip()
            pattern = r'[\"\'\\/\\?\\-_+=\n]'
            cleaned_text = re.sub(pattern, '', text)
            cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
            extracted_data[key] = cleaned_text
        else:
            extracted_data[key] = ""

    # Add DOI field with placeholder value
    extracted_data["DOI"] = "-"

    return extracted_data

def process_json_file(file_path):
    # Load the JSON data
    with open(file_path, 'r', encoding='utf-8') as file:
        data = file.read()

    # Extract the extracted_object section
    extracted_object_match = re.search(r"extracted_object:\n([\s\S]+)", data)
    if extracted_object_match:
        extracted_object_text = extracted_object_match.group(1)
        return extract_from_raw_text(extracted_object_text)
    else:
        print(f"No extracted_object section found in file: {file_path}")
        return None

def process_claims_folder(claims_folder_path):
    combined_data = []
    for file_name in os.listdir(claims_folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(claims_folder_path, file_name)
            extracted_data = process_json_file(file_path)
            if extracted_data:
                combined_data.append(extracted_data)

    # Save the combined data to a new JSON file in the Claims folder
    combined_file_path = os.path.join(claims_folder_path, 'combined_data.json')
    with open(combined_file_path, 'w', encoding='utf-8') as combined_file:
        json.dump(combined_data, combined_file, indent=4)
    print(f"Combined data saved to {combined_file_path}")

def process_directory(directory):
    for folder_name in os.listdir(directory):
        folder_path = os.path.join(directory, folder_name)
        if os.path.isdir(folder_path):
            claims_folder_path = os.path.join(folder_path, 'Claims')
            if os.path.exists(claims_folder_path):
                process_claims_folder(claims_folder_path)

def main():
    root_directory = 'RootDirectoryOfPatentData'  # Replace with the path to your directory
    process_directory(root_directory)

main()
# Out:
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1814/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1815/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2266/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1757/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1759/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2062/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1732/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1760/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1758/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2052/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2258/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1756/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2205/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1734/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2229/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1727/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2024/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2211/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2079/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1728/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2226/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2040/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2078/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2071/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2076/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1272/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1210/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1217/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1808/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1228/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1221/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1466/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1226/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1806/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1219/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1227/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1218/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1807/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1467/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1220/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1800/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1216/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1229/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1211/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1469/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1252/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1263/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1817/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1819/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1479/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1254/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1811/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1209/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1816/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2207/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1798/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1796/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2237/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1739/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2033/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2069/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2056/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1755/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2223/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2249/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1740/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2075/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2214/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2010_1725/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1214/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1213/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1225/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1222/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1271/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2011_2303/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1223/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1224/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1212/Claims/combined_data.json
# Combined data saved to /Users/AliTarik/Documents/LastAttempt/2009_1215/Claims/combined_data.json
