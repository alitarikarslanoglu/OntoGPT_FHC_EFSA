# %%
import os
import json
import requests
import time
import re

def load_and_fix_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

def query_semantic_scholar(title, api_key):
    url = f"https://api.semanticscholar.org/graph/v1/paper/search?query={title}&fields=title,authors,year,journal,externalIds&limit=1"
    headers = {"x-api-key": api_key}
    time.sleep(1.5)
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        results = data.get('data', [])
        if results:
            return results[0]
    else:
        print(f"API request failed with status code {response.status_code}")
    return None

def update_citations(file_path, api_key):
    citations_data = load_and_fix_json(file_path)
    for key, citation in citations_data.items():
        title = citation.get('title')
        if title:
            result = query_semantic_scholar(title, api_key)
            if result:
                citation['doi'] = result.get('externalIds', {}).get('DOI')
                citation['pmid'] = result.get('externalIds', {}).get('PubMed')
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(citations_data, file, indent=4)

def process_directory(input_directory, api_key):
    for root, dirs, files in os.walk(input_directory):
        for dir in dirs:
            citations_file_path = os.path.join(root, dir, 'claims', 'citation_references.json')
            if os.path.exists(citations_file_path):
                print(f"Updating citations in {citations_file_path}")
                update_citations(citations_file_path, api_key)
def main():
    api_key = 'SemantiScholarAPIKey'
    input_directory = 'RootDirectoryOfPatentData'
    process_directory(input_directory, api_key)


main()
# Out:
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1814/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1815/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2266/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1757/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1759/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2062/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1732/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1760/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1758/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2052/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2258/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1756/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2205/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1734/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2229/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1727/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2024/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2211/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2079/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1728/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2226/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2040/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2078/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2071/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2076/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1272/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1210/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1217/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1808/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1228/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1221/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1466/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1226/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1806/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1219/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1227/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1218/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1807/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1467/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1220/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1800/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1216/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1229/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1211/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1469/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1252/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1263/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1817/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1819/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1479/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1254/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1811/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1209/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1816/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2207/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1798/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1796/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2237/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1739/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2033/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2069/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2056/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1755/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2223/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2249/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1740/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2075/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2214/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2010_1725/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1214/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1213/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1225/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1222/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1271/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2011_2303/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1223/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1224/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1212/claims/citation_references.json
# Updating citations in /Users/AliTarik/Documents/LastAttempt/2009_1215/claims/citation_references.json
